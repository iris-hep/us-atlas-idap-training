# %% [markdown]
# # ServiceX Problem Set
#
# This problem set is designed to be completed in tandem with the [ServiceX User Guide](https://tryservicex.org). The information to answer all of the questions can be found through that documentation.
#
# The problems in this problem set are designed less to teach how to use ServiceX, but more to help show where ServiceX can be used in your prexisting work flows and tasks. To show this each problem will have brief bit of text motivating why we included that problem.

# %% [markdown]
# ## Problem 1 - Get Structure

# %% [markdown]
# **Motivation:** There are many times where you need to download a file or dataset from the grid, but you are not sure if it has everything in it you will need to do your task. Currently this means you need to download a file to see what it has in it. With ServiceX you don't have to!
#
# **Problem:** Use the `get_structure()` function in order to see if this dataset has the `jet_EMFrac_NOSYS` branch. Once you have run the search, run it again and see how much faster it runs a second time.
#
# **Hint:** You are able to filter the branches that come back to you, check the docs on how to do that!

# %%
from servicex_analysis_utils import get_structure

ntuple_dataset = "user.acordeir:michigan-tutorial.displaced-signal.root" # Use this dataset to run the command.

# run get structure in the print statement below:

print()

# %% [markdown]
# ## Problem 2 - 15 Minute Challenge (Uproot)

# %% [markdown]
# **Motivation:** The 15 minute challenge has been designed to show people how quickly you can get data with ServiceX! The motivation to your workflows is when you need to get quick information from a dataset and make sure that things look like you expect.
#
# **Problem:** Complete the 15 minute challenge and generate the two plots that it shows at the end. You can copy and paste here, no need to type the entire thing out.

# %%
# Complete the Uproot version of this challenge here!

# %% [markdown]
# ## Problem 3 - Plot Truth ALP pT
#
# **Motivation:** When we run the ServiceX query it caches the data for us so that we don't have to redownload it everytime and wait for the transform.
#
# **Problem:** Start this problem by creating a new deliver that uses the same spec. Call the output variable something different. Then plot the Truth ALP Eta that we get back from this deliver function.

# %%
# Plot truth alp eta here! Make sure to have a deliver() in this cell. You won't need to copy the entire spec.

# %% [markdown]
# ## Problem 4 - Change the Truth ALP Eta cut
#
# **Motivation** - PHYSLITE can be a mystery in how to get your information out of it. We will now do the 15 minute challenge again, but for getting data out of a DAOD.
#
# **Problem** - Go back to the 15 minute challenge documentation and do the FuncADL version of the challenge.

# %%
# Complete the FuncADL 15 Minute Challenge here!

# %% [markdown]
# ## Probelm 5 - Alter the GeV cut on the jets
#
# **Problem:** Take the query that is sent to ServiceX for the FuncADL challenge and change the 40 GeV cut to be 100 Gev. Plot the differences.
#
# **Hint:** Notice how the query runs on the ServiceX backend again. This is because you changed the query in a way that it need to pull the data again.

# %%
# Change the gev cut here. I would copy the example above as a starting point.
